# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#https://ollama.com/download

# %%
#download and install application

# %%
#@powershell terminal:
#ollama run llama3.2

# %% [markdown]
# ![image.png](attachment:image.png)
